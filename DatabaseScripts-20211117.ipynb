-- %% [markdown]
-- # [gStringKustomGuitarDb]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [gStringKustomGuitarDb]    Script Date: 2021/11/17 13:19:21 ******/
CREATE DATABASE [gStringKustomGuitarDb]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'gStringKustomGuitarDb', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.SQLEXPRESS01\MSSQL\DATA\gStringKustomGuitarDb.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'gStringKustomGuitarDb_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.SQLEXPRESS01\MSSQL\DATA\gStringKustomGuitarDb_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [gStringKustomGuitarDb] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [gStringKustomGuitarDb].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [gStringKustomGuitarDb] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET ARITHABORT OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET  DISABLE_BROKER 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET  MULTI_USER 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [gStringKustomGuitarDb] SET DB_CHAINING OFF 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [gStringKustomGuitarDb] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[TM_AUD_Audit]

-- %%
USE [gStringKustomGuitarDb]
GO

-- %%
/****** Object:  Table [dbo].[TM_AUD_Audit]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TM_AUD_Audit](
	[aud_id] [int] IDENTITY(1,1) NOT NULL,
	[aud_event_datetime] [datetime] NULL,
	[aud_event_name] [varchar](max) NULL,
	[aud_event_action] [varchar](max) NULL,
	[usr_id] [int] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TM_CAT_Categories]

-- %%
/****** Object:  Table [dbo].[TM_CAT_Categories]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TM_CAT_Categories](
	[cat_id] [int] IDENTITY(1,1) NOT NULL,
	[cat_code] [varchar](50) NULL,
	[cat_name] [varchar](50) NOT NULL,
	[cat_isactive] [varchar](50) NULL,
 CONSTRAINT [PK_TM_CAT_Categories] PRIMARY KEY CLUSTERED 
(
	[cat_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TM_PRD_Product]

-- %%
/****** Object:  Table [dbo].[TM_PRD_Product]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TM_PRD_Product](
	[prd_id] [int] IDENTITY(1,1) NOT NULL,
	[prd_code] [varchar](10) NULL,
	[prd_name] [varchar](50) NOT NULL,
	[prd_description] [varchar](100) NULL,
	[prd_price] [money] NULL,
	[prd_image] [varchar](max) NULL,
	[cat_id] [int] NULL,
 CONSTRAINT [PK_TM_PRD_Product] PRIMARY KEY CLUSTERED 
(
	[prd_name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TM_USR_Users]

-- %%
/****** Object:  Table [dbo].[TM_USR_Users]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TM_USR_Users](
	[usr_id] [int] IDENTITY(1,1) NOT NULL,
	[usr_name] [nvarchar](50) NULL,
	[usr_surname] [nvarchar](50) NULL,
	[usr_email] [nvarchar](50) NOT NULL,
	[usr_password] [nvarchar](50) NULL,
	[usr_isactive] [int] NULL,
 CONSTRAINT [PK_TM_USR_Users] PRIMARY KEY CLUSTERED 
(
	[usr_email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PD_PRODUCTS]

-- %%
/****** Object:  StoredProcedure [dbo].[PD_PRODUCTS]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PD_PRODUCTS]
	@prd_id int
AS
BEGIN
	SET NOCOUNT ON;
	
	DELETE FROM TM_PRD_Product
     WHERE [prd_id] = @prd_id;

END
GO

-- %% [markdown]
-- # [dbo].[PI_AUDIT_TRACE]

-- %%
/****** Object:  StoredProcedure [dbo].[PI_AUDIT_TRACE]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PI_AUDIT_TRACE]
    @aud_event_name  varchar(max),
    @aud_event_action varchar(max),
    @usr_id int
AS
BEGIN
	SET NOCOUNT ON;
	INSERT INTO [dbo].[TM_AUD_Audit]
           ([aud_event_datetime]
           ,[aud_event_name]
           ,[aud_event_action]
           ,[usr_id])
     VALUES
           (GETDATE()
           ,@aud_event_name
           ,@aud_event_action
           ,@usr_id)
END

GO

-- %% [markdown]
-- # [dbo].[PI_CATEGORIES]

-- %%
/****** Object:  StoredProcedure [dbo].[PI_CATEGORIES]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PI_CATEGORIES]
    @cat_code varchar(50),
    @cat_name varchar(50)
AS
BEGIN
	SET NOCOUNT ON;
	INSERT INTO [dbo].[TM_CAT_Categories]
           ([cat_code]
           ,[cat_name]
           ,[cat_isactive])
     VALUES
           (@cat_code
           ,@cat_name
           ,1)
END
GO

-- %% [markdown]
-- # [dbo].[PI_PRODUCTS]

-- %%
/****** Object:  StoredProcedure [dbo].[PI_PRODUCTS]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PI_PRODUCTS]
	@prd_code varchar(10),
	@prd_name varchar(50),
	@prd_description varchar(100),
	@prd_price money,
	@prd_image varchar(max),
	@cat_id int
AS
BEGIN
	SET NOCOUNT ON;
	INSERT INTO [dbo].[TM_PRD_Product]
               ([prd_code]
               ,[prd_name]
               ,[prd_description]
               ,[prd_price]
               ,[prd_image]
               ,[cat_id])
         VALUES
               (@prd_code
               ,@prd_name
               ,@prd_description
               ,@prd_price
               ,@prd_image
               ,@cat_id)

		SELECT @@IDENTITY AS [@@IDENTITY];
END
select * from [dbo].[TM_PRD_Product]
GO

-- %% [markdown]
-- # [dbo].[PI_USER]

-- %%
/****** Object:  StoredProcedure [dbo].[PI_USER]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--EXEC PI_USER 'koos', 'oosthuizen', 'koos@test.co.za', '123'
CREATE PROCEDURE [dbo].[PI_USER] 
	 @usr_name nvarchar(50),
     @usr_surname nvarchar(50),
     @usr_email nvarchar(50),
     @usr_password nvarchar(50)
AS
BEGIN
	SET NOCOUNT ON;
    INSERT INTO [dbo].[TM_USR_Users]
           ([usr_name]
           ,[usr_surname]
           ,[usr_email]
           ,[usr_password]
           ,[usr_isactive])
     VALUES
           (@usr_name
           ,@usr_surname
           ,@usr_email
           ,@usr_password
           ,1)

	SELECT @@IDENTITY AS [@@IDENTITY];
END
GO

-- %% [markdown]
-- # [dbo].[PS_AUD_Audit_Trace]

-- %%
/****** Object:  StoredProcedure [dbo].[PS_AUD_Audit_Trace]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PS_AUD_Audit_Trace]	
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;
	SELECT [aud].[aud_id],
	       [usr].[usr_name] + ' ' + [usr].[usr_surname]  as FullNames   
		  ,[aud].[aud_event_datetime]
		  ,[aud].[aud_event_name]
		  ,[aud].[aud_event_action]
	  FROM [dbo].[TM_AUD_Audit] aud INNER JOIN [dbo].[TM_USR_Users] usr ON aud.usr_id = usr.usr_id
END
GO

-- %% [markdown]
-- # [dbo].[PS_CATEGORIES]

-- %%
/****** Object:  StoredProcedure [dbo].[PS_CATEGORIES]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PS_CATEGORIES] 
  @cat_id varchar(50) = -1
AS
BEGIN
	SET NOCOUNT ON;
	
	IF (@cat_id = -1)
	BEGIN
	SELECT [cat_id]
          ,[cat_code]
          ,[cat_name]
          ,[cat_isactive]
      FROM [dbo].[TM_CAT_Categories]	
   END
   ELSE
   BEGIN
   SELECT  [cat_id]
          ,[cat_code]
          ,[cat_name]
          ,[cat_isactive]
      FROM [dbo].[TM_CAT_Categories]	
	  WHERE [cat_id] = @cat_id
   END
END
GO

-- %% [markdown]
-- # [dbo].[PS_LOGIN]

-- %%
/****** Object:  StoredProcedure [dbo].[PS_LOGIN]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--EXEC PS_LOGIN 'shakings@hotmail.co.za','P@ssw0rd'
CREATE PROCEDURE [dbo].[PS_LOGIN]
	@email VARCHAR(50), @password VARCHAR(50)
	AS
BEGIN
 SET NOCOUNT ON;
 SELECT [usr_id]
       ,[usr_name]
       ,[usr_surname]
       ,[usr_email]
   FROM [dbo].[TM_USR_Users]
  WHERE [usr_email] =@email AND [usr_password] =@password  AND [usr_isactive]=1

END
GO

-- %% [markdown]
-- # [dbo].[PS_PRODUCTS]

-- %%
/****** Object:  StoredProcedure [dbo].[PS_PRODUCTS]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[PS_PRODUCTS]
  @prd_id int = -1
AS
BEGIN
	SET NOCOUNT ON;
	IF (@prd_id = -1)
	BEGIN
	SELECT [prd].[prd_id]
          ,[prd].[prd_code]
          ,[prd].[prd_name]
          ,[prd].[prd_description]
          ,[prd].[prd_price]
          ,[prd].[prd_image]
		  ,[cat].[cat_id]
          ,[cat].[cat_name]
      FROM [dbo].[TM_PRD_Product] prd INNER JOIN [dbo].[TM_CAT_Categories] cat 
	    ON prd.cat_id = cat.cat_id
	 END
	 ELSE
	 BEGIN
	 SELECT [prd].[prd_id]
          ,[prd].[prd_code]
          ,[prd].[prd_name]
          ,[prd].[prd_description]
          ,[prd].[prd_price]
          ,[prd].[prd_image]
		  ,[cat].[cat_id]
          ,[cat].[cat_name]
      FROM [dbo].[TM_PRD_Product] prd INNER JOIN [dbo].[TM_CAT_Categories] cat 
	    ON prd.cat_id = cat.cat_id AND [prd].[prd_id] = @prd_id
	 END
END

--select * from [dbo].[TM_CAT_Categories]
GO

-- %% [markdown]
-- # [dbo].[PU_CATEGORIES]

-- %%
/****** Object:  StoredProcedure [dbo].[PU_CATEGORIES]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PU_CATEGORIES]
    @cat_id int,
    @cat_code varchar(50),
    @cat_name varchar(50),
	@cat_isactive int
AS
BEGIN
	SET NOCOUNT ON;
	UPDATE [dbo].[TM_CAT_Categories]
       SET [cat_code] = @cat_code
          ,[cat_name] = @cat_name
          ,[cat_isactive] = @cat_isactive
     WHERE [cat_id] = @cat_id

END
GO

-- %% [markdown]
-- # [dbo].[PU_PRODUCTS]

-- %%
/****** Object:  StoredProcedure [dbo].[PU_PRODUCTS]    Script Date: 2021/11/17 13:19:21 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[PU_PRODUCTS]
	@prd_id int,
	@prd_code varchar(10),
	@prd_name varchar(50),
	@prd_description varchar(100),
	@prd_price money,
	@prd_image varchar(100),
	@cat_id int
AS
BEGIN
	SET NOCOUNT ON;
	
	UPDATE [dbo].[TM_PRD_Product]
       SET [prd_code] = @prd_code
          ,[prd_name] = @prd_name
          ,[prd_description] = @prd_description
          ,[prd_price] = @prd_price
          ,[prd_image] = @prd_image
          ,[cat_id] = @cat_id 
     WHERE [prd_id] = @prd_id;

END
GO

-- %% [markdown]
-- # [gStringKustomGuitarDb]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [gStringKustomGuitarDb] SET  READ_WRITE 
GO
